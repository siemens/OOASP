# %% [markdown]
# # UI Racks
# Copyright (c) 2022 Siemens AG Oesterreich
# SPDX-License-Identifier: MIT

# %%
# run this once (or after every restart)
# %cd ..
# Out:
# c:\projects\OOASP\asp_interactive_configuration

# %%
from ooasp.interactive import InteractiveConfigurator
from ooasp.kb import OOASPKnowledgeBase
from IPython.display import Image
puzzles_kb = OOASPKnowledgeBase.from_file("puzzles_v1","./examples/puzzles/kb.lp")
puzzles_kb.save_png("examples/puzzles")
iconf = InteractiveConfigurator(puzzles_kb,"puzzles_config_1",["./examples/puzzles/constraints.lp"])
Image("examples/puzzles/puzzles_v1.png")

# %%
from ooasp.ui import OOASPUI
ui = OOASPUI(iconf)
# Out:
# HTML(value='<style>div.output_scroll { height: 44em; }</style>')
# GridspecLayout(children=(VBox(children=(HTML(value='<h2>History</h2>'), Label(value='0. start')), layout=Layou…
